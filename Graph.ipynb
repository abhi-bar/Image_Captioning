# %%
# Define the loss values as a list
loss_values = [1.5776, 1.5474, 1.5193, 1.4902, 1.4625, 1.4324, 1.4058, 1.3798, 1.3465, 1.3210, 1.2954, 1.2673, 1.2446, 1.2223, 1.1928, 1.1698, 1.1491, 1.1219, 1.0982, 1.0773, 1.0546, 1.0318, 1.0080, 0.9872, 0.9652, 0.9482, 0.9294, 0.9120, 0.8954, 0.8792, 0.8545, 0.8402, 0.8224, 0.8086, 0.7899, 0.7773, 0.7661, 0.7456, 0.7321, 0.7255, 0.7106, 0.6976, 0.6893, 0.6740]

# Calculate the difference between each loss value and the previous one
differences = [loss_values[i] - loss_values[i-1] for i in range(1, len(loss_values))]

# Print the differences to show how the loss values are decreasing
print("Differences in loss values:")
for difference in differences:
    print(f"- {difference:.4f}")

# Optionally, you can also plot the loss values and differences to visualize the trend
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# Plot the loss values
plt.plot(range(1, len(loss_values) + 1), loss_values, marker='o', label='Loss')

# Plot the differences
plt.plot(range(2, len(loss_values) + 1), differences, marker='o', label='Difference')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.title("Loss and Difference over Epochs")
plt.show()
# Out:
# Differences in loss values:
# - -0.0302
# - -0.0281
# - -0.0291
# - -0.0277
# - -0.0301
# - -0.0266
# - -0.0260
# - -0.0333
# - -0.0255
# - -0.0256
# - -0.0281
# - -0.0227
# - -0.0223
# - -0.0295
# - -0.0230
# - -0.0207
# - -0.0272
# - -0.0237
# - -0.0209
# - -0.0227
# - -0.0228
# - -0.0238
# - -0.0208
# - -0.0220
# - -0.0170
# - -0.0188
# - -0.0174
# - -0.0166
# - -0.0162
# - -0.0247
# - -0.0143
# - -0.0178
# - -0.0138
# - -0.0187
# - -0.0126
# - -0.0112
# - -0.0205
# - -0.0135
# - -0.0066
# - -0.0149
# - -0.0130
# - -0.0083
# - -0.0153

# %%
# Define the values as a list
values = [0.5595, 0.5636, 0.5689, 0.574, 0.5790, 0.5857, 0.5898, 0.5946, 0.6031, 0.6072, 0.6117, 0.6189, 0.6243, 0.6289, 0.6355, 0.6402, 0.6452, 0.6527, 0.6574, 0.6643, 0.6708, 0.6754, 0.6828, 0.6887, 0.6938, 0.6978, 0.7041, 0.7098, 0.7124, 0.7190, 0.7252, 0.7295, 0.7350, 0.7396, 0.7454, 0.7482, 0.7538, 0.7591, 0.7636, 0.7651, 0.7697, 0.7739, 0.7753, 0.7792]

# Calculate the difference between each value and the previous one
differences = [values[i] - values[i-1] for i in range(1, len(values))]

# Print the differences to show how the values are increasing
print("Differences in values:")
for difference in differences:
   print(f"- {difference:.4f}")

# Optionally, you can also plot the values and differences to visualize the trend
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# Plot the values
plt.plot(range(1, len(values) + 1), values, marker='o', label='Accuracy Values')

# Plot the differences
plt.plot(range(2, len(values) + 1), differences, marker='o', label='Difference')

plt.xlabel('Index')  # Use a general label for the x-axis
plt.ylabel('Accuracy Value')
plt.legend()
plt.grid(True)
plt.title("Values and Difference over Indices")
plt.show()
# Out:
# Differences in values:
# - 0.0041
# - 0.0053
# - 0.0051
# - 0.0050
# - 0.0067
# - 0.0041
# - 0.0048
# - 0.0085
# - 0.0041
# - 0.0045
# - 0.0072
# - 0.0054
# - 0.0046
# - 0.0066
# - 0.0047
# - 0.0050
# - 0.0075
# - 0.0047
# - 0.0069
# - 0.0065
# - 0.0046
# - 0.0074
# - 0.0059
# - 0.0051
# - 0.0040
# - 0.0063
# - 0.0057
# - 0.0026
# - 0.0066
# - 0.0062
# - 0.0043
# - 0.0055
# - 0.0046
# - 0.0058
# - 0.0028
# - 0.0056
# - 0.0053
# - 0.0045
# - 0.0015
# - 0.0046
# - 0.0042
# - 0.0014
# - 0.0039

# %%
import matplotlib.pyplot as plt

# Loss values
loss_values = [1.5776, 1.5474, 1.5193, 1.4902, 1.4625, 1.4324, 1.4058, 1.3798, 1.3465, 1.3210, 1.2954, 1.2673, 1.2446, 1.2223, 1.1928, 1.1698, 1.1491, 1.1219, 1.0982, 1.0773, 1.0546, 1.0318, 1.0080, 0.9872, 0.9652, 0.9482, 0.9294, 0.9120, 0.8954, 0.8792, 0.8545, 0.8402, 0.8224, 0.8086, 0.7899, 0.7773, 0.7661, 0.7456, 0.7321, 0.7255, 0.7106, 0.6976, 0.6893, 0.6740]

# Other values
other_values = [0.5595, 0.5636, 0.5689, 0.574, 0.5790, 0.5857, 0.5898, 0.5946, 0.6031, 0.6072, 0.6117, 0.6189, 0.6243, 0.6289, 0.6355, 0.6402, 0.6452, 0.6527, 0.6574, 0.6643, 0.6708, 0.6754, 0.6828, 0.6887, 0.6938, 0.6978, 0.7041, 0.7098, 0.7124, 0.7190, 0.7252, 0.7295, 0.7350, 0.7396, 0.7454, 0.7482, 0.7538, 0.7591, 0.7636, 0.7651, 0.7697, 0.7739, 0.7753, 0.7792]

# Create the plot
plt.figure(figsize=(10, 6))

# Plot loss values
plt.plot(range(1, len(loss_values) + 1), loss_values, marker='o', label='Loss')

# Plot other values
plt.plot(range(1, len(other_values) + 1), other_values, marker='o', label='Accuracy')

# Customize the plot
plt.xlabel('Epoch')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.title("Loss and Accuracy over Epochs")
plt.show()
